# %% [markdown]
# ### Last week (questions?)

# %% [markdown]
# #### Lists

# %%
shoplist = ['apple', 'mango', 'carrot', 'banana']
name = 'Gilad'

# Indexing or 'Subscription' operation #
print 'Item 0 is', shoplist[0]
print 'Item 1 is', shoplist[1]
print 'Item 2 is', shoplist[2]
print 'Item 3 is', shoplist[3]
print 'Item -1 is', shoplist[-1]
print 'Item -2 is', shoplist[-2]
print 'Character 0 is', name[0]
# Out:
# Item 0 is apple
# Item 1 is mango
# Item 2 is carrot
# Item 3 is banana
# Item -1 is banana
# Item -2 is carrot
# Character 0 is G

# %%
# Slicing on a list #
print 'Item 1 to 3 is', shoplist[1:3]
print 'Item 2 to end is', shoplist[2:]
print 'Item 1 to -1 is', shoplist[1:-1]
print 'Item start to end is', shoplist[:]
# Out:
# Item 1 to 3 is ['mango', 'carrot']
# Item 2 to end is ['carrot', 'banana']
# Item 1 to -1 is ['mango', 'carrot']
# Item start to end is ['apple', 'mango', 'carrot', 'banana']

# %%
# Slicing on a string #
print 'characters 1 to 3 is', name[1:3]
print 'characters 2 to end is', name[2:]
print 'characters 1 to -1 is', name[1:-1]
print 'characters start to end is', name[:]
# Out:
# characters 1 to 3 is il
# characters 2 to end is lad
# characters 1 to -1 is ila
# characters start to end is Gilad

# %% [markdown]
# #### List comprehension

# %%
# extremely useful way to derive a new list from an existing list

listone = [2, 3, 4]
listone
# Out:
# [2, 3, 4]

# %%
new_array = []

for i in listone:
    if i>2:
        new_array.append(2*i)
        
print new_array
# Out:
# [6, 8]

# %%
[i for i in listone]
# Out:
# [2, 3, 4]

# %%
[i*2 for i in listone]
# Out:
# [4, 6, 8]

# %%
[2*i for i in listone if i > 2]
# Out:
# [6, 8]

# %%
True and False
# Out:
# False

# %%
print [i for i in list(alphabet)[:5]] # AKA List comprehension (note that strings are iterables!)

# %%
print [i.upper() for i in alphabet[::3]]

# %% [markdown]
# ### H/W Questions

# %% [raw]
# 1. Load all first names from the names file on your remote machine (located at: '/class/itpmssd/datasets/names.txt') into a data structure.
#     - Which data structure did you choose? And Why?

# %%
# who chose a dict? list? why?

# %%
f = open('/class/itpmssd/datasets/names.txt','r')
for line in f.readlines():
    print line
# Out:
# Aaron
#
# Aaron
#
# Abbey
#
# Abbie
#
# Abby
#
# Abdul
#
# Abe
#
# Abel
#
# Abigail
#
# Abraham
#
# Abram
#
# Ada
#
# Adah
#
# Adalberto
#
# Adaline
#
# Adam
#
# Adam
#
# Adan
#
# Addie
#
# Adela
#
# Adelaida
#
# Adelaide
#
# Adele
#
# Adelia
#
# Adelina
#
# Adeline
#
# Adell
#
# Adella
#
# Adelle
#
# Adena
#
# Adina
#
# Adolfo
#
# Adolph
#
# Adria
#
# Adrian
#
# Adrian
#
# Adriana
#
# Adriane
#
# Adrianna
#
# Adrianne
#
# Adrien
#
# Adriene
#
# Adrienne
#
# Afton
#
# Agatha
#
# Agnes
#
# Agnus
#
# Agripina
#
# Agueda
#
# Agustin
#
# Agustina
#
# Ahmad
#
# Ahmed
#
# Ai
#
# Aida
#
# Aide
#
# Aiko
#
# Aileen
#
# Ailene
#
# Aimee
#
# Aisha
#
# Aja
#
# Akiko
#
# Akilah
#
# Al
#
# Alaina
#
# Alaine
#
# Alan
#
# Alana
#
# Alane
#
# Alanna
#
# Alayna
#
# Alba
#
# Albert
#
# Albert
#
# Alberta
#
# Albertha
#
# Albertina
#
# Albertine
#
# Alberto
#
# Albina
#
# Alda
#
# Alden
#
# Aldo
#
# Alease
#
# Alec
#
# Alecia
#
# Aleen
#
# Aleida
#
# Aleisha
#
# Alejandra
#
# Alejandrina
#
# Alejandro
# ...

# %%
f = open('/class/itpmssd/datasets/names.txt','r')
names = []

for line in f.readlines():
    print line.strip()
    names.append(line.strip())
# Out:
#  Aaron
# Aaron
# Abbey
# Abbie
# Abby
# Abdul
# Abe
# Abel
# Abigail
# Abraham
# Abram
# Ada
# Adah
# Adalberto
# Adaline
# Adam
# Adam
# Adan
# Addie
# Adela
# Adelaida
# Adelaide
# Adele
# Adelia
# Adelina
# Adeline
# Adell
# Adella
# Adelle
# Adena
# Adina
# Adolfo
# Adolph
# Adria
# Adrian
# Adrian
# Adriana
# Adriane
# Adrianna
# Adrianne
# Adrien
# Adriene
# Adrienne
# Afton
# Agatha
# Agnes
# Agnus
# Agripina
# Agueda
# Agustin
# Agustina
# Ahmad
# Ahmed
# Ai
# Aida
# Aide
# Aiko
# Aileen
# Ailene
# Aimee
# Aisha
# Aja
# Akiko
# Akilah
# Al
# Alaina
# Alaine
# Alan
# Alana
# Alane
# Alanna
# Alayna
# Alba
# Albert
# Albert
# Alberta
# Albertha
# Albertina
# Albertine
# Alberto
# Albina
# Alda
# Alden
# Aldo
# Alease
# Alec
# Alecia
# Aleen
# Aleida
# Aleisha
# Alejandra
# Alejandrina
# Alejandro
# Alena
# Alene
# Alesha
# Aleshia
# Alesia
# Alessandra
# Aleta
# Aletha
# Alethea
# Alethia
# Alex
# Alex
# Alexa
# Alexander
# Alexander
# Alexandra
# Alexandria
# Alexia
# Alexis
# ...

# %%
# From Maria Fang:

# I chose to make it a list. Because I'm most familiar with handling lists and dictionaries 
# are scary.

names = open('/class/itpmssd/datasets/names.txt')
nameList = names.read()
nameList.split('\n')
# Out:
# ['Aaron',
#  'Aaron',
#  'Abbey',
#  'Abbie',
#  'Abby',
#  'Abdul',
#  'Abe',
#  'Abel',
#  'Abigail',
#  'Abraham',
#  'Abram',
#  'Ada',
#  'Adah',
#  'Adalberto',
#  'Adaline',
#  'Adam',
#  'Adam',
#  'Adan',
#  'Addie',
#  'Adela',
#  'Adelaida',
#  'Adelaide',
#  'Adele',
#  'Adelia',
#  'Adelina',
#  'Adeline',
#  'Adell',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adina',
#  'Adolfo',
#  'Adolph',
#  'Adria',
#  'Adrian',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriene',
#  'Adrienne',
#  'Afton',
#  'Agatha',
#  'Agnes',
#  'Agnus',
#  'Agripina',
#  'Agueda',
#  'Agustin',
#  'Agustina',
#  'Ahmad',
#  'Ahmed',
#  'Ai',
#  'Aida',
#  'Aide',
#  'Aiko',
#  'Aileen',
#  'Ailene',
#  'Aimee',
#  'Aisha',
#  'Aja',
#  'Akiko',
#  'Akilah',
#  'Al',
#  'Alaina',
#  'Alaine',
#  'Alan',
#  'Alana',
#  'Alane',
#  'Alanna',
#  'Alayna',
#  'Alba',
#  'Albert',
#  'Albert',
#  'Alberta',
#  'Albertha',
#  'Albertina',
#  'Albertine',
# ...

# %% [raw]
# 2. Let's explore this dataset:
#     - How many names are included? How many unique names?
#     - Sort alphabetically and print all names.
#     - print only names that appear multiple times.

# %%
# from someone:

e = 0
for i in a:
    c = 0
    for j in a: 
      
        if j == i:
            c += 1
            if c > 1:
                e += 1
                break
print(5494 - e) + "unique names"

# %%
# my solution

print 'total names:', len(names)
print 'unique names:', len(set(names))
# Out:
# total names: 5494
# unique names: 5163

# %%
print 'sorted:'
print sorted(names)
# Out:
# sorted:
# ...

# %%
names.count('Ali')
# Out:
# 2

# %%
set([x for x in names if names.count(x)>1])
# Out:
# {'Aaron',
#  'Adam',
#  'Adrian',
#  'Albert',
#  'Alex',
#  'Alexander',
#  'Alexis',
#  'Ali',
#  'Allen',
#  'Alva',
#  'Andre',
#  'Andrea',
#  'Andrew',
#  'Angel',
#  'Angelo',
#  'Anthony',
#  'Antonia',
#  'Antonio',
#  'Ariel',
#  'Arthur',
#  'Ashley',
#  'Aubrey',
#  'Augustine',
#  'Austin',
#  'Avery',
#  'Bennie',
#  'Bernie',
#  'Berry',
#  'Billie',
#  'Billy',
#  'Blair',
#  'Blake',
#  'Bobbie',
#  'Bobby',
#  'Brandon',
#  'Brett',
#  'Brian',
#  'Britt',
#  'Cameron',
#  'Carey',
#  'Carl',
#  'Carlos',
#  'Carmen',
#  'Carol',
#  'Carrol',
#  'Carroll',
#  'Cary',
#  'Casey',
#  'Cecil',
#  'Chang',
#  'Charles',
#  'Charlie',
#  'Chi',
#  'Chong',
#  'Chris',
#  'Christian',
#  'Christopher',
#  'Chung',
#  'Clair',
#  'Clarence',
#  'Claude',
#  'Cleo',
#  'Clyde',
#  'Cody',
#  'Colby',
#  'Connie',
#  'Corey',
#  'Cory',
#  'Courtney',
#  'Cruz',
#  'Curtis',
#  'Dale',
#  'Dallas',
#  'Dan',
#  'Dana',
#  'Daniel',
#  'Dannie',
#  'Darnell',
#  'Daryl',
# ...

# %% [raw]
# 3. Create a function that receives a string as input and prints it out only if it has AT LEAST THREE characters that appear in YOUR first name.
#     - Iterate over all names in the names data structure created in the previous steps, and apply the function, printing out the relevant names.

# %%
# at least 3 characters -> not first 3 characters

# %%
# instead of this, iterate over characters + use lower()
for letter in name:
    if letter == "h" or letter == "u" or letter == "g" or letter == "o":
        letterCounter = letterCounter + 1
    elif letter == "H" or letter == "U" or letter == "G" or letter == "O":
        letterCounter = letterCounter + 1

# %%
# This is awesome
import re 

def threeFirstNameChars(name):
    if re.search(r"[kathleen]{3,}", name.lower()):
        print name
        
threeFirstNameChars("Kat")

# %%
# my solution

MY_NAME = 'gilad'

def my_func(input_str):
    cnt = 0
    
    for c in set([c for c in MY_NAME]):
        if c in input_str.lower():
            cnt+=1
    
    if cnt>=3:
        print input_str

# %%
for name in set(names):
    my_func(name)
# Out:
# Phylicia
# Shalonda
# Nida
# Laronda
# Idella
# Araceli
# Talitha
# Senaida
# Julietta
# Claud
# Kaleigh
# Margarite
# Rosalina
# Kallie
# Hilma
# Petronila
# Elia
# Marceline
# Melodi
# Sandi
# Apolonia
# Marcelina
# Kraig
# Arielle
# Claude
# Bailey
# Alishia
# Idell
# Hailey
# Delicia
# Margarita
# Dionna
# Gregoria
# Isreal
# Agustin
# Trinidad
# Angie
# Carmelita
# Elisabeth
# Felipa
# Renaldo
# Luigi
# Reginia
# Gaynelle
# Clotilde
# Fredia
# Laurine
# Mandi
# Wilhemina
# Randell
# Glenna
# Ardelia
# Danelle
# Olga
# Filomena
# Della
# Edgardo
# Clair
# Deloise
# Juliana
# Larita
# Gidget
# Lakita
# Felicita
# Miranda
# Darla
# Dylan
# Malissa
# Evelina
# Evelia
# Wilhelmina
# Lenard
# Ali
# Liliana
# Elda
# Gabriela
# Gabriele
# Inga
# Librada
# Latoria
# Willa
# Thalia
# Leonia
# Emerald
# Daina
# Daine
# Mallie
# Goldie
# Dwight
# Alycia
# Mariela
# Delinda
# India
# Clarine
# Eliza
# Gaylene
# Gina
# William
# Glinda
# Mafalda
# Rosalinda
# Earlie
# Argelia
# Gianna
# ...

# %%
MY_NAME = 'gilaaadaaggll'
# Out:
# {'a', 'd', 'g', 'i', 'l'}
